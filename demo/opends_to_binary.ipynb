# %%
import os
import shutil
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

db_path = '/home/choppy/tesis/opends_dataset/sem_dataset'
train = os.path.join(db_path, 'train') # images - labels
val = os.path.join(db_path, 'validation') # images - labels
final_dir = './opends_tf_unet'

# %%
train_dict = {
    'images': sorted([os.path.join(train, 'images', x) for x in os.listdir(os.path.join(train, 'images'))]),
    'labels': sorted([os.path.join(train, 'labels', x) for x in os.listdir(os.path.join(train, 'labels'))]),
}

val_dict = {
    'images': sorted([os.path.join(val, 'images', x) for x in os.listdir(os.path.join(val, 'images'))]),
    'labels': sorted([os.path.join(val, 'labels', x) for x in os.listdir(os.path.join(val, 'labels'))]),
}

# %%
# 0: bg
# 1: sclera
# 2: iris
# 3: pupil

def change_label_name(im_name, suffix):
    if '/' in im_name:
        im_name = im_name.split('/')[-1]
        
    name, ext = im_name.split('.')
    final_name = name + suffix
    return '.'.join([final_name, ext])

def imsave(fname, image):
    plt.imsave(fname, image, cmap='gray')

def get_masks(label):
    # zeros matrix
    sclera = np.zeros(label.shape, dtype=np.bool)
    iris = np.zeros(label.shape, dtype=np.bool)
    pupil = np.zeros(label.shape, dtype=np.bool)
    
    sclera[np.where(label == 1)] = True
    iris[np.where(label == 2)] = True
    pupil[np.where(label == 3)] = True
    
    return sclera, iris, pupil

# %%
max_images = 100
debug = True

if not os.path.exists(final_dir):
    os.makedirs(os.path.join(final_dir, 'train'))
    os.makedirs(os.path.join(final_dir, 'validation'))

# train
for img, lb in zip(train_dict['images'][:max_images], train_dict['labels'][:max_images]):
    sclera, iris, pupil = get_masks(np.load(lb)) # obtain masks
    
    # obtain mask name
    # if image name is 000000002610.png
    # label name will be 000000002610_labelname.png
#     sclera_lb = os.path.join(final_dir, 'train', change_label_name(img, '_sclera'))
    iris_lb = os.path.join(final_dir, 'train', change_label_name(img, '_iris'))
#     pupil_lb = os.path.join(final_dir, 'train', change_label_name(img, '_pupil'))
    
    # save labels
#     imsave(sclera_lb, sclera)
    imsave(iris_lb, iris)
#     imsave(pupil_lb, pupil)
    
    # save original image
    im_name = img.split('/')[-1] # get image name
    shutil.copyfile(img, os.path.join(final_dir, 'train', im_name)) # copy image
    if debug:
#         print(f'write {sclera_lb}')
        print(f'write {iris_lb}')
#         print(f'write {pupil_lb}')
        print(f'write {im_name}\n')

# validation
for img, lb in zip(val_dict['images'][:max_images], val_dict['labels'][:max_images]):
    sclera, iris, pupil = get_masks(np.load(lb)) # obtain masks
    
    # obtain mask name
    # if image name is 000000002610.png
    # label name will be 000000002610_labelname.png
#     sclera_lb = os.path.join(final_dir, 'validation', change_label_name(img, '_sclera'))
    iris_lb = os.path.join(final_dir, 'validation', change_label_name(img, '_iris'))
#     pupil_lb = os.path.join(final_dir, 'validation', change_label_name(img, '_pupil'))
    
    # save labels
#     imsave(sclera_lb, sclera)
    imsave(iris_lb, iris)
#     imsave(pupil_lb, pupil)
    
    # save original image
    im_name = img.split('/')[-1] # get image name
    shutil.copyfile(img, os.path.join(final_dir, 'validation', im_name)) # copy image
    if debug:
#         print(f'write {sclera_lb}')
        print(f'write {iris_lb}')
#         print(f'write {pupil_lb}')
        print(f'write {im_name}\n')
# Out:
# write ./opends_tf_unet/train/000000002610_iris.png
# write 000000002610.png
#
# write ./opends_tf_unet/train/000000002611_iris.png
# write 000000002611.png
#
# write ./opends_tf_unet/train/000000002612_iris.png
# write 000000002612.png
#
# write ./opends_tf_unet/train/000000002613_iris.png
# write 000000002613.png
#
# write ./opends_tf_unet/train/000000002614_iris.png
# write 000000002614.png
#
# write ./opends_tf_unet/train/000000002615_iris.png
# write 000000002615.png
#
# write ./opends_tf_unet/train/000000002616_iris.png
# write 000000002616.png
#
# write ./opends_tf_unet/train/000000002617_iris.png
# write 000000002617.png
#
# write ./opends_tf_unet/train/000000002618_iris.png
# write 000000002618.png
#
# write ./opends_tf_unet/train/000000002619_iris.png
# write 000000002619.png
#
# write ./opends_tf_unet/train/000000002620_iris.png
# write 000000002620.png
#
# write ./opends_tf_unet/train/000000002621_iris.png
# write 000000002621.png
#
# write ./opends_tf_unet/train/000000002622_iris.png
# write 000000002622.png
#
# write ./opends_tf_unet/train/000000002623_iris.png
# write 000000002623.png
#
# write ./opends_tf_unet/train/000000002624_iris.png
# write 000000002624.png
#
# write ./opends_tf_unet/train/000000002625_iris.png
# write 000000002625.png
#
# write ./opends_tf_unet/train/000000002626_iris.png
# write 000000002626.png
#
# write ./opends_tf_unet/train/000000002627_iris.png
# write 000000002627.png
#
# write ./opends_tf_unet/train/000000002628_iris.png
# write 000000002628.png
#
# write ./opends_tf_unet/train/000000002629_iris.png
# write 000000002629.png
#
# write ./opends_tf_unet/train/000000002630_iris.png
# write 000000002630.png
#
# write ./opends_tf_unet/train/000000002631_iris.png
# write 000000002631.png
#
# write ./opends_tf_unet/train/000000002632_iris.png
# write 000000002632.png
#
# write ./opends_tf_unet/train/000000002633_iris.png
# write 000000002633.png
#
# write ./opends_tf_unet/train/000000002634_iris.png
# write 000000002634.png
#
# write ./opends_tf_unet/train/000000002635_iris.png
# write 000000002635.png
#
# write ./opends_tf_unet/train/000000002636_iris.png
# write 000000002636.png
#
# write ./opends_tf_unet/train/000000002637_iris.png
# write 000000002637.png
#
# write ./opends_tf_unet/train/000000002638_iris.png
# write 000000002638.png
#
# write ./opends_tf_unet/train/000000002639_iris.png
# write 000000002639.png
#
# write ./opends_tf_unet/train/000000002640_iris.png
# write 000000002640.png
#
# write ./opends_tf_unet/train/000000002641_iris.png
# write 000000002641.png
#
# write ./opends_tf_unet/train/000000002642_iris.png
# write 000000002642.png
#
# write ./opends_tf_unet/train/000000002643_iris.png
# write 000000002643.png
#
# write ./opends_tf_unet/train/000000002644_iris.png
# write 000000002644.png
#
# write ./opends_tf_unet/train/000000002645_iris.png
# write 000000002645.png
#
# write ./opends_tf_unet/train/000000002646_iris.png
# write 000000002646.png
#
# write ./opends_tf_unet/train/000000002647_iris.png
# write 000000002647.png
#
# write ./opends_tf_unet/train/000000002648_iris.png
# write 000000002648.png
#
# write ./opends_tf_unet/train/000000002649_iris.png
# write 000000002649.png
#
# write ./opends_tf_unet/train/000000002650_iris.png
# write 000000002650.png
#
# write ./opends_tf_unet/train/000000002651_iris.png
# write 000000002651.png
#
# write ./opends_tf_unet/train/000000002652_iris.png
# write 000000002652.png
#
# write ./opends_tf_unet/train/000000002653_iris.png
# write 000000002653.png
#
# write ./opends_tf_unet/train/000000002654_iris.png
# write 000000002654.png
#
# write ./opends_tf_unet/train/000000002655_iris.png
# write 000000002655.png
#
# write ./opends_tf_unet/train/000000002656_iris.png
# write 000000002656.png
#
# write ./opends_tf_unet/train/000000002657_iris.png
# write 000000002657.png
#
# write ./opends_tf_unet/train/000000002658_iris.png
# write 000000002658.png
#
# write ./opends_tf_unet/train/000000002659_iris.png
# write 000000002659.png
#
# write ./opends_tf_unet/train/000000002660_iris.png
# write 000000002660.png
#
# write ./opends_tf_unet/train/000000002661_iris.png
# write 000000002661.png
#
# write ./opends_tf_unet/train/000000002662_iris.png
# write 000000002662.png
#
# write ./opends_tf_unet/train/000000002663_iris.png
# write 000000002663.png
#
# write ./opends_tf_unet/train/000000002664_iris.png
# write 000000002664.png
#
# write ./opends_tf_unet/train/000000002665_iris.png
# write 000000002665.png
#
# write ./opends_tf_unet/train/000000002666_iris.png
# write 000000002666.png
#
# write ./opends_tf_unet/train/000000002667_iris.png
# write 000000002667.png
#
# write ./opends_tf_unet/train/000000002668_iris.png
# write 000000002668.png
#
# write ./opends_tf_unet/train/000000002669_iris.png
# write 000000002669.png
#
# write ./opends_tf_unet/train/000000002670_iris.png
# write 000000002670.png
#
# write ./opends_tf_unet/train/000000002671_iris.png
# write 000000002671.png
#
# write ./opends_tf_unet/train/000000002672_iris.png
# write 000000002672.png
#
# write ./opends_tf_unet/train/000000002673_iris.png
# write 000000002673.png
#
# write ./opends_tf_unet/train/000000002674_iris.png
# write 000000002674.png
#
# write ./opends_tf_unet/train/000000002675_iris.png
# write 000000002675.png
#
# write ./opends_tf_unet/train/000000002676_iris.png
# write 000000002676.png
#
# write ./opends_tf_unet/train/000000002677_iris.png
# write 000000002677.png
#
# write ./opends_tf_unet/train/000000002678_iris.png
# write 000000002678.png
#
# write ./opends_tf_unet/train/000000002679_iris.png
# write 000000002679.png
#
# write ./opends_tf_unet/train/000000002680_iris.png
# write 000000002680.png
#
# write ./opends_tf_unet/train/000000002681_iris.png
# write 000000002681.png
#
# write ./opends_tf_unet/train/000000002682_iris.png
# write 000000002682.png
#
# write ./opends_tf_unet/train/000000002683_iris.png
# write 000000002683.png
#
# write ./opends_tf_unet/train/000000002684_iris.png
# write 000000002684.png
#
# write ./opends_tf_unet/train/000000002685_iris.png
# write 000000002685.png
#
# write ./opends_tf_unet/train/000000002686_iris.png
# write 000000002686.png
#
# write ./opends_tf_unet/train/000000002687_iris.png
# write 000000002687.png
#
# write ./opends_tf_unet/train/000000002688_iris.png
# write 000000002688.png
#
# write ./opends_tf_unet/train/000000002689_iris.png
# write 000000002689.png
#
# write ./opends_tf_unet/train/000000002690_iris.png
# write 000000002690.png
#
# write ./opends_tf_unet/train/000000002691_iris.png
# write 000000002691.png
#
# write ./opends_tf_unet/train/000000002692_iris.png
# write 000000002692.png
#
# write ./opends_tf_unet/train/000000002693_iris.png
# write 000000002693.png
#
# write ./opends_tf_unet/train/000000002694_iris.png
# write 000000002694.png
#
# write ./opends_tf_unet/train/000000002695_iris.png
# write 000000002695.png
#
# write ./opends_tf_unet/train/000000002696_iris.png
# write 000000002696.png
#
# write ./opends_tf_unet/train/000000002697_iris.png
# write 000000002697.png
#
# write ./opends_tf_unet/train/000000002698_iris.png
# write 000000002698.png
#
# write ./opends_tf_unet/train/000000002699_iris.png
# write 000000002699.png
#
# write ./opends_tf_unet/train/000000002700_iris.png
# write 000000002700.png
#
# write ./opends_tf_unet/train/000000002701_iris.png
# write 000000002701.png
#
# write ./opends_tf_unet/train/000000002702_iris.png
# write 000000002702.png
#
# write ./opends_tf_unet/train/000000002703_iris.png
# write 000000002703.png
#
# write ./opends_tf_unet/train/000000002704_iris.png
# write 000000002704.png
#
# write ./opends_tf_unet/train/000000002705_iris.png
# write 000000002705.png
#
# write ./opends_tf_unet/train/000000002706_iris.png
# write 000000002706.png
#
# write ./opends_tf_unet/train/000000002707_iris.png
# write 000000002707.png
#
# write ./opends_tf_unet/train/000000002708_iris.png
# write 000000002708.png
#
# write ./opends_tf_unet/train/000000002709_iris.png
# write 000000002709.png
#
# write ./opends_tf_unet/validation/000000262446_iris.png
# write 000000262446.png
#
# write ./opends_tf_unet/validation/000000262447_iris.png
# write 000000262447.png
#
# write ./opends_tf_unet/validation/000000262448_iris.png
# write 000000262448.png
#
# write ./opends_tf_unet/validation/000000262449_iris.png
# write 000000262449.png
#
# write ./opends_tf_unet/validation/000000262450_iris.png
# write 000000262450.png
#
# write ./opends_tf_unet/validation/000000262451_iris.png
# write 000000262451.png
#
# write ./opends_tf_unet/validation/000000262452_iris.png
# write 000000262452.png
#
# write ./opends_tf_unet/validation/000000262453_iris.png
# write 000000262453.png
#
# write ./opends_tf_unet/validation/000000262454_iris.png
# write 000000262454.png
#
# write ./opends_tf_unet/validation/000000262455_iris.png
# write 000000262455.png
#
# write ./opends_tf_unet/validation/000000262456_iris.png
# write 000000262456.png
#
# write ./opends_tf_unet/validation/000000262457_iris.png
# write 000000262457.png
# write ./opends_tf_unet/validation/000000262458_iris.png
# write 000000262458.png
#
# write ./opends_tf_unet/validation/000000262459_iris.png
# write 000000262459.png
#
# write ./opends_tf_unet/validation/000000262460_iris.png
# write 000000262460.png
#
# write ./opends_tf_unet/validation/000000262461_iris.png
# write 000000262461.png
#
# write ./opends_tf_unet/validation/000000262462_iris.png
# write 000000262462.png
#
# write ./opends_tf_unet/validation/000000262463_iris.png
# write 000000262463.png
#
# write ./opends_tf_unet/validation/000000262464_iris.png
# write 000000262464.png
#
# write ./opends_tf_unet/validation/000000262465_iris.png
# write 000000262465.png
#
# write ./opends_tf_unet/validation/000000262466_iris.png
# write 000000262466.png
#
# write ./opends_tf_unet/validation/000000262467_iris.png
# write 000000262467.png
#
# write ./opends_tf_unet/validation/000000262468_iris.png
# write 000000262468.png
#
# write ./opends_tf_unet/validation/000000262469_iris.png
# write 000000262469.png
#
# write ./opends_tf_unet/validation/000000262470_iris.png
# write 000000262470.png
#
# write ./opends_tf_unet/validation/000000262471_iris.png
# write 000000262471.png
#
# write ./opends_tf_unet/validation/000000262472_iris.png
# write 000000262472.png
#
# write ./opends_tf_unet/validation/000000262473_iris.png
# write 000000262473.png
#
# write ./opends_tf_unet/validation/000000262474_iris.png
# write 000000262474.png
#
# write ./opends_tf_unet/validation/000000262475_iris.png
# write 000000262475.png
#
# write ./opends_tf_unet/validation/000000262476_iris.png
# write 000000262476.png
#
# write ./opends_tf_unet/validation/000000262477_iris.png
# write 000000262477.png
#
# write ./opends_tf_unet/validation/000000262478_iris.png
# write 000000262478.png
#
# write ./opends_tf_unet/validation/000000262479_iris.png
# write 000000262479.png
#
# write ./opends_tf_unet/validation/000000262480_iris.png
# write 000000262480.png
#
# write ./opends_tf_unet/validation/000000262481_iris.png
# write 000000262481.png
#
# write ./opends_tf_unet/validation/000000262482_iris.png
# write 000000262482.png
#
# write ./opends_tf_unet/validation/000000262483_iris.png
# write 000000262483.png
#
# write ./opends_tf_unet/validation/000000262484_iris.png
# write 000000262484.png
#
# write ./opends_tf_unet/validation/000000262485_iris.png
# write 000000262485.png
#
# write ./opends_tf_unet/validation/000000262486_iris.png
# write 000000262486.png
#
# write ./opends_tf_unet/validation/000000262487_iris.png
# write 000000262487.png
#
# write ./opends_tf_unet/validation/000000262488_iris.png
# write 000000262488.png
#
# write ./opends_tf_unet/validation/000000262489_iris.png
# write 000000262489.png
#
# write ./opends_tf_unet/validation/000000262490_iris.png
# write 000000262490.png
#
# write ./opends_tf_unet/validation/000000262491_iris.png
# write 000000262491.png
#
# write ./opends_tf_unet/validation/000000262492_iris.png
# write 000000262492.png
#
# write ./opends_tf_unet/validation/000000262493_iris.png
# write 000000262493.png
#
# write ./opends_tf_unet/validation/000000262494_iris.png
# write 000000262494.png
#
# write ./opends_tf_unet/validation/000000262495_iris.png
# write 000000262495.png
#
# write ./opends_tf_unet/validation/000000262496_iris.png
# write 000000262496.png
#
# write ./opends_tf_unet/validation/000000262497_iris.png
# write 000000262497.png
#
# write ./opends_tf_unet/validation/000000262498_iris.png
# write 000000262498.png
#
# write ./opends_tf_unet/validation/000000262499_iris.png
# write 000000262499.png
#
# write ./opends_tf_unet/validation/000000262500_iris.png
# write 000000262500.png
#
# write ./opends_tf_unet/validation/000000262501_iris.png
# write 000000262501.png
#
# write ./opends_tf_unet/validation/000000262502_iris.png
# write 000000262502.png
#
# write ./opends_tf_unet/validation/000000262503_iris.png
# write 000000262503.png
#
# write ./opends_tf_unet/validation/000000262504_iris.png
# write 000000262504.png
#
# write ./opends_tf_unet/validation/000000262505_iris.png
# write 000000262505.png
#
# write ./opends_tf_unet/validation/000000262506_iris.png
# write 000000262506.png
#
# write ./opends_tf_unet/validation/000000262507_iris.png
# write 000000262507.png
#
# write ./opends_tf_unet/validation/000000262508_iris.png
# write 000000262508.png
#
# write ./opends_tf_unet/validation/000000262509_iris.png
# write 000000262509.png
#
# write ./opends_tf_unet/validation/000000262510_iris.png
# write 000000262510.png
#
# write ./opends_tf_unet/validation/000000262511_iris.png
# write 000000262511.png
#
# write ./opends_tf_unet/validation/000000262512_iris.png
# write 000000262512.png
#
# write ./opends_tf_unet/validation/000000262513_iris.png
# write 000000262513.png
#
# write ./opends_tf_unet/validation/000000262514_iris.png
# write 000000262514.png
#
# write ./opends_tf_unet/validation/000000262515_iris.png
# write 000000262515.png
#
# write ./opends_tf_unet/validation/000000262516_iris.png
# write 000000262516.png
#
# write ./opends_tf_unet/validation/000000262517_iris.png
# write 000000262517.png
#
# write ./opends_tf_unet/validation/000000262518_iris.png
# write 000000262518.png
#
# write ./opends_tf_unet/validation/000000262519_iris.png
# write 000000262519.png
#
# write ./opends_tf_unet/validation/000000262520_iris.png
# write 000000262520.png
#
# write ./opends_tf_unet/validation/000000262521_iris.png
# write 000000262521.png
#
# write ./opends_tf_unet/validation/000000262522_iris.png
# write 000000262522.png
#
# write ./opends_tf_unet/validation/000000262523_iris.png
# write 000000262523.png
#
# write ./opends_tf_unet/validation/000000262524_iris.png
# write 000000262524.png
#
# write ./opends_tf_unet/validation/000000262525_iris.png
# write 000000262525.png
#
# write ./opends_tf_unet/validation/000000262526_iris.png
# write 000000262526.png
#
# write ./opends_tf_unet/validation/000000262527_iris.png
# write 000000262527.png
#
# write ./opends_tf_unet/validation/000000262528_iris.png
# write 000000262528.png
#
# write ./opends_tf_unet/validation/000000262529_iris.png
# write 000000262529.png
#
# write ./opends_tf_unet/validation/000000262530_iris.png
# write 000000262530.png
#
# write ./opends_tf_unet/validation/000000262531_iris.png
# write 000000262531.png
#
# write ./opends_tf_unet/validation/000000262532_iris.png
# write 000000262532.png
#
# write ./opends_tf_unet/validation/000000262533_iris.png
# write 000000262533.png
#
# write ./opends_tf_unet/validation/000000262534_iris.png
# write 000000262534.png
#
# write ./opends_tf_unet/validation/000000262535_iris.png
# write 000000262535.png
#
# write ./opends_tf_unet/validation/000000262536_iris.png
# write 000000262536.png
#
# write ./opends_tf_unet/validation/000000262537_iris.png
# write 000000262537.png
#
# write ./opends_tf_unet/validation/000000262538_iris.png
# write 000000262538.png
#
# write ./opends_tf_unet/validation/000000262539_iris.png
# write 000000262539.png
#
# write ./opends_tf_unet/validation/000000262540_iris.png
# write 000000262540.png
#
# write ./opends_tf_unet/validation/000000262541_iris.png
# write 000000262541.png
#
# write ./opends_tf_unet/validation/000000262542_iris.png
# write 000000262542.png
#
# write ./opends_tf_unet/validation/000000262543_iris.png
# write 000000262543.png
#
# write ./opends_tf_unet/validation/000000262544_iris.png
# write 000000262544.png
#
# write ./opends_tf_unet/validation/000000262545_iris.png
# write 000000262545.png
